# %%
import pandas as pd
import matplotlib.pyplot as plt

# 设置中文显示
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# 读取 Excel 文件
file_path = "C:/Users/wahah/Desktop/干员总览.xlsx"
df = pd.read_excel(file_path, sheet_name='Sheet1')

# %%
#  提取攻击和血量数据
attack = df['攻击']
hp = df['血量']


#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter(hp,attack, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员攻击与血量散点图')  # 设置图的标题
plt.xlabel('血量')  # 设置 x 轴标签
plt.ylabel('攻击')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员攻击与血量散点图.png')
plt.show()  # 显示图形

# %%
wdef = df['物防']
hp = df['血量']


#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( hp,wdef, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员物防与血量散点图')  # 设置图的标题
plt.xlabel('血量')  # 设置 x 轴标签
plt.ylabel('物防')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员物防与血量散点图.png')
plt.show()  # 显示图形

# %%
block = df['阻挡数']
hp = df['血量']


#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( hp,block, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员阻挡数与血量散点图')  # 设置图的标题
plt.xlabel('血量')  # 设置 x 轴标签
plt.ylabel('阻挡数')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员阻挡数与血量散点图.png')
plt.show()  # 显示图形

# %%
coast = df['费用']
hp = df['血量']


#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( hp,coast, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员费用与血量散点图')  # 设置图的标题
plt.xlabel('血量')  # 设置 x 轴标签
plt.ylabel('费用')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员费用与血量散点图.png')
plt.show()  # 显示图形

# %%
hp = df['血量']
fdef = df['法防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( hp,fdef, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员血量与法防散点图')  # 设置图的标题
plt.xlabel('血量')  # 设置 x 轴标签
plt.ylabel('法防')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员法防与血量散点图.png')
plt.show()  # 显示图形

# %%
attack = df['攻击']
wdef = df['物防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( attack,wdef, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员攻击与物防散点图')  # 设置图的标题
plt.xlabel('攻击')  # 设置 x 轴标签
plt.ylabel('物防')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员攻击与物防散点图.png')
plt.show()  # 显示图形

# %%
attack = df['攻击']
fdef = df['法防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( attack,fdef, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员攻击与法防散点图')  # 设置图的标题
plt.xlabel('攻击')  # 设置 x 轴标签
plt.ylabel('法防')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员攻击与法防散点图.png')
plt.show()  # 显示图形

# %%
attack = df['攻击']
coast = df['费用']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( attack,coast, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员攻击与费用散点图')  # 设置图的标题
plt.xlabel('攻击')  # 设置 x 轴标签
plt.ylabel('费用')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员攻击与费用散点图.png')
plt.show()  # 显示图形

# %%
attack = df['攻击']
block = df['阻挡数']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( attack,block, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员攻击与阻挡数散点图')  # 设置图的标题
plt.xlabel('攻击')  # 设置 x 轴标签
plt.ylabel('阻挡数')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员攻击与阻挡数散点图.png')
plt.show()  # 显示图形

# %%
fdef = df['法防']
wdef = df['物防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( wdef,fdef, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员法防与物防散点图')  # 设置图的标题
plt.xlabel('物防')  # 设置 x 轴标签
plt.ylabel('法防')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员法防与物防散点图.png')
plt.show()  # 显示图形

# %%
coast = df['费用']
wdef = df['物防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( wdef,coast, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员费用与物防散点图')  # 设置图的标题
plt.xlabel('物防')  # 设置 x 轴标签
plt.ylabel('费用')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员物防与费用散点图.png')
plt.show()  # 显示图形

# %%
coast = df['费用']
fdef = df['法防']

#  绘制散点图
plt.figure(figsize=(10, 6))  # 设置图的大小

plt.scatter( fdef,coast, marker='o', color='blue', alpha=0.5)  # 绘制散点图
plt.title('干员法防与费用散点图')  # 设置图的标题
plt.xlabel('法防')  # 设置 x 轴标签
plt.ylabel('费用')  # 设置 y 轴标签

plt.grid(True)  # 添加网格线
plt.tight_layout()  # 调整布局，防止标签被切割
plt.savefig('干员法防与费用散点图.png')
plt.show()  # 显示图形
